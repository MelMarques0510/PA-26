# %% [markdown]
# <a href="https://colab.research.google.com/github/MelMarques0510/PA-26/blob/main/c%C3%A1lculo_aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula de programação e algoritimos
#
# * Cálculo da área
#
# # Entrada
#
# * ler lado1
# * ler lado2
#
# # Processamento
#
# área = lado1 x lado2
#
# # Saída
#
# imprimir área

# %%
# cálculo da área

# Entrada

lado1 = 5

lado2 = 4

nome = "Melissa Marques"

# %%
print (nome)
# Out:
# Melissa Marques

# %%
# Processamento

área = lado1 * lado2

# %%
# Saida

print(f"Total da área: {área}")
# Out:
# Total da área: 20

# %%
# Tipos Numéricos

idade = 15 # int
altura = 1.55 # float
número_complexo = 2 + 3j # complex

# Tipos Texto

nome = " Melissa" # str

# Tipo Booleano

esta_chovendo = False # boll
