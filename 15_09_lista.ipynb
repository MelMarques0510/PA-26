# %% [markdown]
# <a href="https://colab.research.google.com/github/MelMarques0510/PA-26/blob/main/15_09_lista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1- Crie uma lista chamada frutas contendo: maça, banana, laranja e morango. Mostre a lista

frutas =["maça, banana, laranja e morango"]
print(frutas)
# Out:
# ['maça, banana, laranja e morango']

# %%
#2- Crie a lista de nomes = {"Rebeca", "Guilherme", "Melissa", "Kyara"}, mostre o primeiro, o segundo e o último nome

nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nomes[0])
print(nomes[1])
print(nomes[3])
# Out:
# Rebeca
# Guilherme
# Kyara

# %%
#3- Crie cores = {"vermelho", "azul", "verde"}. Troque "azul" por "amarelo" e mostre a lista

cores = ["vermelho", "azul", "verde"]
cores[1]= "amarelo"
print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
#4- Crie alunos = {"Nicolas", "Wendel", "Pyetra"}. Adicione "Petros" usando append().

alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
#5. Crie animais = ["cachorro", "gato", "coelho", "passarinho"]. Remova "coelho" usando remove().

animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']
