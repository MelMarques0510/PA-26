# %% [markdown]
# <a href="https://colab.research.google.com/github/MelMarques0510/PA-26/blob/main/22_09_dicion%C3%A1rios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Crie um dicionário chamado aluno contendo: nome, idade e curso. Mostre o dicionário.

aluno = {
    "nome": "Luana",
    "idade":15,
    "curso":"Informática"
}
print(aluno)
# Out:
# {'nome': 'Luana', 'idade': 15, 'curso': 'Informática'}

# %%
#2. Crie um dicionário com nome, idade e curso de um aluno. Mostre cada informação separadamente
aluno = {
    "nome": "William",
    "idade":14,
    "curso":"Informática"
}
print(aluno["nome"])
print(aluno["idade"])
print(aluno["curso"])
# Out:
# William
# 14
# Informática

# %%
#3. Crie um dicionário produto contendo nome, preço e estoque. Altere o preço e mostre o resultado.

produto = {
    "nome": "celular",
    "preço":1000,
    "estoque": 5
}
produto["preço"] = 800
print(produto)
# Out:
# {'nome': 'celular', 'preço': 800, 'estoque': 5}

# %%
#4. Crie um dicionário aluno contendo nome e idade. Depois, adicione a informação curso.

aluno = {
    "nome": "Vitor",
    "idade":16
}
aluno["curso"] = "Informática"
print(aluno)
# Out:
# {'nome': 'Vitor', 'idade': 16, 'curso': 'Informática'}

# %%
#5. Crie um dicionário chamado filme contendo: título, ano, gênero e nota. Depois, mostre cada informação separadamente.

filme = {
    "titulo": "Continência ao amor",
    "ano": 2022,
    "gênero": "romance",
    "nota": 10
}
print(filme["titulo"])
print(filme["ano"])
print(filme["gênero"])
print(filme["nota"])
# Out:
# Continência ao amor
# 2022
# romance
# 10
