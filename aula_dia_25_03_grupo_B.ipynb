# %% [markdown]
# <a href="https://colab.research.google.com/github/MelMarques0510/PA-26/blob/main/aula_dia_25_03_grupo_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Decisões

#Entrada
a = int(input("digite um número: "))
b = int(input("digite um número: "))

if a > b:
    print (f"{a} é maior que {b}")

elif b > a:
    print (f"{a} é menor que {b}")

else:
  print (f"os dois números são iguais")
# Out:
# digite um número: 4
# digite um número: 9
# 4 é menor que 9

# %%
# Fazer uma calculadora simples com 04 operações

print("----------MENU---------")
print("")
print("opção - 1 = SOMA")
print("opção - 2 = SUBTRAÇÃO ")
print("opção - 3 = MULTIPLICAÇÃO")
print("opção - 4 = DIVISÃO")

opcao = int(input("digite sua opção"))

# Entrada

a = float (input("digite um numero: "))
b = float (input("digite um numero: "))

# Processamento

if opcao == 1:
  print(f"a soma é igual a {a + b}")
  print("")

elif opcao == 2:
  print(f"a subtração é igual a {a - b}")
  print("")

elif opcao == 3:
  print(f"a multiplicação é igual a {a * b}")
  print("")

elif opcao == 4:
    if b != 0:
        print(f"a divisão é igual a {a / b}")
        print("")
    else:
        print("Erro: Divisão por zero não é permitida!")
        print("")

else:
    print("Opção inválida!")
    print("")

  # Saida
# Out:
# ----------MENU---------
#
# opção - 1 = SOMA
# opção - 2 = SUBTRAÇÃO
# opção - 3 = MULTIPLICAÇÃO
# opção - 4 = DIVISÃO
# digite sua opção1
# digite um numero: 42
# digite um numero: 24
# a soma é igual a 66.0

# %%
#Entrada
print("digite suas notas AQUI, valores de 0 a 10!")
nota1 = float(input("digite a nota do 1º bimestre"))
nota2 = float(input("digite a nota do 2º bimestre"))
nota3 = float(input("digite a nota do 3º bimestre"))
nota4 = float(input("digite a nota do 4º bimestre"))

#Processamento

resultado = (nota1 + nota2 + nota3 + nota4) / 4

if resultado >= 7:
  print(f"a média das suas notas foi {resultado}, você foi aprovado")

elif resultado >=5:
  print(f"a média das suas notas foi {resultado}, você terá quer fazer recuperação")

else:
  print(f"a média das suas notas foi {resultado}, você foi reprovado")
# Out:
# digite suas notas AQUI, valores de 0 a 10!
# digite a nota do 1º bimestre9
# digite a nota do 2º bimestre9
# digite a nota do 3º bimestre8
# digite a nota do 4º bimestre7
# a média das suas notas foi 8.25, você foi aprovado
